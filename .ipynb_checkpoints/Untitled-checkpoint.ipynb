# %%
import matplotlib.pyplot as plt
import numpy as np
from Functions import *

# %load_ext autoreload
# %autoreload 2

# %%
f = one_D_shallow
grad_f = grad_one_D_shallow

# %%
X = np.linspace(-2 , 2 , 100)

inp = np.array(X)
out  = f(inp)

plt.plot(inp, out)
plt.show()

# %%
min(out)
# Out:
# 0.00040568528025379427
